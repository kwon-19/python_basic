# %%
a = 4.24e10
a
# Out:
# 42400000000.0

# %%
a = 0o177
a
# Out:
# 127

# %%
a = 0x8ff
a
# Out:
# 2303

# %%
a = 3
b = 4

# %%
a**b
# Out:
# 81

# %%
7 % 3
# Out:
# 1

# %%
7//4
# Out:
# 1

# %%
a = "Life is too short\nYou need python."
print(a)
# Out:
# Life is too short
# You need python.

# %%
"I eat %d apples." %3
# Out:
# 'I eat 3 apples.'

# %%
"I eat %s apples."%"five"
# Out:
# 'I eat five apples.'

# %%
a = 3
"I eat %d apples."%a
# Out:
# 'I eat 3 apples.'

# %%
a = "%0.2f"%1.12345
a
# Out:
# '1.12'

# %%
"%10s"%"hi"
# Out:
# '        hi'

# %%
"{:<10}".format('hi')
# Out:
# 'hi        '

# %%
"%-10s"%"hi"
# Out:
# 'hi        '

# %%
f"{'hi':<10}"
# Out:
# 'hi        '

# %%
str(2) + "hi"
# Out:
# '2hi'

# %%
a = [1,2,3]

a.append('four')
a
# Out:
# [1, 2, 3, 'four']

# %%
a = [3,7,5,1,4]
a.sort()
a
# Out:
# [1, 3, 4, 5, 7]

# %%
a = [1,2,3]
a.insert(0,4)
a
# Out:
# [4, 1, 2, 3]

# %%
a = [1,2,3,1,1,1]
a.count(1)
# Out:
# 4

# %%
a = [1,2,3]
a.extend([3,4])
a
# Out:
# [1, 2, 3, 3, 4]

# %%
a = "123"
b = "hi"

s1 = set(a+b)
s1
# Out:
# {'1', '2', '3', 'h', 'i'}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

a & b
# Out:
# {3}

# %%
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
a-b
# Out:
# {1, 2}

# %%
a.update([7,8,9])
a
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
money= False

if money:
    print('ㅇ')
else:
    print('x')
# Out:
# x

# %%
money = 2000

if money >= 1900:
    print('0')
else:
    print('1')
# Out:
# 0

# %%
money = 2000

if money >= 1900:
    pass
else:
    print('1')

# %%
pocket = "money, paper"

if "card" in pocket:
    print('택시를 타고 가라')
elif "obox" in pocket:
    print('박스를 타고 가라')
elif "money" in pocket:
    print('돈 좀')
# Out:
# 돈 좀

# %%
if "money" in pocket: print("돈 좀")
else: print("미안")
# Out:
# 돈 좀

# %%
score=70
message= "성공" if score >= 60 else "실패"
print(message)
# Out:
# 성공s

# %%
score = 100
message="성공" if score >=60 else "실패"
print(message)
# Out:
# 성공

# %%
배고픔 = "배고파"

message = "짬뽕" if 배고픔 == "배고파" else "자장"
print(message)
# Out:
# 짬뽕

# %%
변수 = 객체
        "문자열", 숫자
        [] 리스트
        () 튜플
        {'':''} 딕셔너리

# %%
s = set([1,2,3])
s
# Out:
# {1, 2, 3}
